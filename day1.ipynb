# %% [markdown]
# <a href="https://colab.research.google.com/github/SamudralaAjaykumarrr/python_upgrade/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
name = "Ajay"
age= 23
height= 5.9


print(name,type(name))
print(age, type(age))
print(height,type(height))
# Out:
# Ajay <class 'str'>
# 23 <class 'int'>
# 5.9 <class 'float'>

# %%
print("Hello Ajay, Welcome to Day 1 ")
# Out:
# Hello Ajay, Welcome to Day 1

# %%
Your_name= input("What is your name = ")
print("Nice To Meet You, "+ Your_name)
# Out:
# What is your name = Ajay
# Nice To Meet You, Ajay

# %%
#Simple Greeting Program

name = input("Enter Your name: ")
age = input("Enter Your age: ")
print("Hello " +name +"!")
print("You Are "+age +" Years old.")
# Out:
# Enter Your name: Ajay
# Enter Your age: 25
# Hello Ajay!
# You Are 25 Years old.

# %%
print(input("My country Name is: "))
# Out:
# My country Name is: India
# India
