# %% [markdown]
# <a href="https://colab.research.google.com/github/SamudralaAjaykumarrr/python_upgrade/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a, b):   # parameters
    return a + b

add(3, 5)        # arguments
# Out:
# 8

# %%
def square(x):
    return x * x

result = square(4)

# %%
def greet(name):
    print("Hello", name)

# %%
def greet(name="User"):
    print("Hello", name)

greet()
greet("Ajay")
# Out:
# Hello User
# Hello Ajay

# %%
def math_ops(a, b):
    return a+b, a-b, a*b

x, y, z = math_ops(5, 3)

# %%
def add(a, b):
    return a + b

print(add(3, 7))
# Out:
# 10

# %%
def greet(name):
    print("Hello", name)

greet("Ajay")
# Out:
# Hello Ajay

# %%
def welcome(name="Guest"):
    print("Welcome", name)

welcome()
welcome("Ajay")
# Out:
# Welcome Guest
# Welcome Ajay

# %%
def calculations(a, b):
    return a+b, a-b, a*b

sum_, diff_, prod_ = calculations(10, 5)
print(sum_, diff_, prod_)
# Out:
# 15 5 50

# %%
x = 100

def demo():
    x = 50
    print("Inside:", x)

demo()
print("Outside:", x)
# Out:
# Inside: 50
# Outside: 100

# %%
def say_hello():
    print("Hello")

say_hello()
# Out:
# Hello

# %%
def greet(name,age):
    print("Hello", name,age)

greet("rani","25")
# Out:
# Hello rani 25

# %%
def add(a, b):
    return a + b

add(7,0.5)
# Out:
# 7.5

# %%
def is_even(n):
    return n % 2 == 0
is_even(29.75)
# Out:
# False

# %%
def welcome(name="User"):
    print("Welcome", name)
welcome()
# Out:
# Welcome User

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print(result)
# Out:
# 8

# %%
def check_pass(marks):
    if marks >= 60:
        return "Pass"
    else:
        return "Fail"

status = check_pass(72)
print(status)
# Out:
# Pass

# %%
def check_pass(marks):
    if marks >= 60:
        return "Pass"
    else:
        return "Fail"

print(check_pass(72))
print(check_pass(85))
# Out:
# Pass
# Pass

# %%
def double(n):
    return n * 2
double(9)
# Out:
# 18

# %%
def check_sign(n):
    if n >= 0:
        return "Positive"
    else:
        return "Negative"
check_sign(-98)
# Out:
# 'Negative'

# %%
def triple(n):
    return n * 3

print(triple(7))
# Out:
# 21

# %%
def square(n):
  return n * n

square(135)
# Out:
# 18225

# %%
def check_age(age):
    if age >= 18:
        return "Adult"
    else:
        return "Minor"

print(check_age(9))
print(check_age(45))
# Out:
# Minor
# Adult

# %%
def count_items(items):
  return len(items)

numbers=[1,2,3,4,5,6,7,8]
print(count_items(numbers))
# Out:
# 8

# %%
def double(n):
    return n * 2

for i in [1, 2, 3, 4,78]:
    print(double(i))
# Out:
# 2
# 4
# 6
# 8
# 156
